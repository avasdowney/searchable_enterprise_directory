# %% [markdown]
# # Generate Data for Searchable Enterprise Directory Application

# %%
# import necessary packages

import csv
import random

# %% [markdown]
# ### Set up dicts and lists to create data

# %%
# Lists of possible names

first_names = ["Ava", "Noah", "Jacob", "Liam", "Noah", "Oliver", "James", "Elijah", "William", "Henry", "Lucas", "Benjamin", "Theodore",
               "Olivia", "Emma", "Charlotte", "Amelia", "Sophia", "Isabella", "Mia", "Evelyn", "Luna"]

last_names = ["Downey", "Ramdial", "Lettick", "Smith", "Johnson", "Williams", "Jones", "Brown", "Garcia", "Miller", "Davis", 
              "Rodriguez", "Martinez", "Hernandez", "Wilson", "Lopez", "Anderson", "Thomas", "Moore", "Jackson"]

# %%
# dictionaries needed to make data have some correlation

work_location_mult = {
    "Hartford, CT" : 1.217,
    "Saint Paul, MN" : 1.135,
    "Hunt Valley, MD" : 1.117,
    "New York, NY" : 1.670
}

job_role_mult = {
    "Junior Software Engineer" : 1.3,
    "Senior Software Engineer" : 2.12,
    "Software Engineer Manager" : 2.66,
    "Junior Data Engineer" : 1.5,
    "Senior Data Engineer" : 2.30,
    "Data Engineer Manager" : 2.60,
    "HR Representative" : 0.73,
    "HR Specialist" : 1,
    "HR Manager" : 1.66
}

job_roles_t1 = ['Software Engineer Manager', 'Data Engineer Manager', 'HR Manager']
job_roles_swe = ['Senior Software Engineer', 'Junior Software Engineer']
job_roles_de = ['Senior Data Engineer', 'Junior Data Engineer']
job_roles_hr = ['HR Specialist', 'HR Representative']

# %%
# constants among all rows

password = "Password123!"

# %% [markdown]
# ### generate the data

# %%
# generate phone number
# code modified from https://stackoverflow.com/questions/26226801/making-random-phone-number-xxx-xxx-xxxx

def gen_phone_num():
    first = str(random.randint(600,999))
    second = str(random.randint(1,888)).zfill(3)

    last = (str(random.randint(1,9998)).zfill(4))
    while last in ['1111','2222','3333','4444','5555','6666','7777','8888']:
        last = (str(random.randint(1,9998)).zfill(4))
        
    return '{}-{}-{}'.format(first,second, last)

# %%
# generate salary with noise multiplier

def gen_salary(job_role, work_location):
    salary = 60000 * job_role_mult.get(job_role) * work_location_mult.get(work_location)
    salary = salary * random.uniform(0.93, 1.08 ) # noise
    return round(salary, 2)

# %%
NUM_ROWS = 999
data_rows = []

# make CEO employee
name = "Alan Schnitzer"
employee_id = 10000
phone_number = gen_phone_num()
job_role = "CEO"
work_location = "Hartford, CT"
salary = 16778800
manager_id = 10000

data_row = [
    name,
    password,
    employee_id,
    phone_number,
    job_role,
    work_location,
    salary,
    manager_id
]

# Add the data row to the list
data_rows.append(data_row)

for x in range(NUM_ROWS):
    name = "{} {}".format(random.choice(first_names), random.choice(last_names))
    employee_id = x + 10001
    phone_number = gen_phone_num()
    work_location = random.choice(list(work_location_mult.keys()))

    # determine manager and job role
    if (x % 20 == 0): # management roles reporting to CEO
        job_role = random.choice(job_roles_t1)
        manager_id = 10000
    elif (data_rows[x-(x%20)+1][4] == "Software Engineer Manager"): # report to swe manager
        job_role = random.choice(job_roles_swe)
        manager_id = data_rows[x-(x%20)+1][2]
    elif (data_rows[x-(x%20)+1][4] == "Data Engineer Manager"): # report to de manager
        job_role = random.choice(job_roles_de)
        manager_id = data_rows[x-(x%20)+1][2]
    elif (data_rows[x-(x%20)+1][4] == "HR Manager"): # report to hr manager
        job_role = random.choice(job_roles_hr)
        manager_id = data_rows[x-(x%20)+1][2]

    salary = gen_salary(job_role, work_location)

    data_row = [
        name,
        password,
        employee_id,
        phone_number,
        job_role,
        work_location,
        salary,
        manager_id
    ]

    # Add the data row to the list
    data_rows.append(data_row)

# %%
# test row outputs

print(data_rows[0])
print(data_rows[1])
print(data_rows[10])
print(data_rows[11])
print(data_rows[999])
# Out:
# ['Alan Schnitzer', 'Password123!', 10000, '730-415-0968', 'CEO', 'Hartford, CT', 16778800, 10000]
# ['Evelyn Smith', 'Password123!', 10001, '604-745-4842', 'Data Engineer Manager', 'Hartford, CT', 189612.01, 10000]
# ['Lucas Davis', 'Password123!', 10010, '907-101-6700', 'Junior Data Engineer', 'Saint Paul, MN', 107196.53, 10001]
# ['Jacob Downey', 'Password123!', 10011, '647-756-0020', 'Junior Data Engineer', 'Hunt Valley, MD', 97882.12, 10001]
# ['Amelia Thomas', 'Password123!', 10999, '656-872-0799', 'Senior Data Engineer', 'Hartford, CT', 157702.87, 10981]

# %%
import pandas as pd
df = pd.DataFrame(data_rows)
df.head(45)
# Out:
#                     0             1      2             3  \
# 0      Alan Schnitzer  Password123!  10000  730-415-0968
# 1        Evelyn Smith  Password123!  10001  604-745-4842
# 2      Noah Hernandez  Password123!  10002  689-440-5017
# 3   Theodore Martinez  Password123!  10003  886-613-9930
# 4        Noah Jackson  Password123!  10004  860-141-3394
# 5      William Downey  Password123!  10005  685-012-2885
# 6       Lucas Ramdial  Password123!  10006  826-250-3325
# 7      Oliver Ramdial  Password123!  10007  736-103-2551
# 8        Amelia Lopez  Password123!  10008  910-374-6511
# 9         Noah Garcia  Password123!  10009  842-426-3909
# 10        Lucas Davis  Password123!  10010  907-101-6700
# 11       Jacob Downey  Password123!  10011  647-756-0020
# 12         Liam Brown  Password123!  10012  735-521-1320
# 13       Elijah Jones  Password123!  10013  634-211-4072
# 14       Noah Johnson  Password123!  10014  931-084-8590
# 15       Ava Anderson  Password123!  10015  983-284-9800
# 16       Lucas Downey  Password123!  10016  954-845-8520
# 17      Noah Anderson  Password123!  10017  958-834-4240
# 18   Charlotte Downey  Password123!  10018  791-173-8764
# 19        Luna Garcia  Password123!  10019  748-393-3383
# 20       Olivia Davis  Password123!  10020  850-241-6333
# 21    Charlotte Davis  Password123!  10021  936-773-8998
# 22      Evelyn Wilson  Password123!  10022  783-090-8742
# 23       Lucas Garcia  Password123!  10023  772-850-7455
# 24         Ava Downey  Password123!  10024  983-561-5124
# 25        Noah Wilson  Password123!  10025  621-639-1430
# 26         Liam Smith  Password123!  10026  882-353-7717
# 27      Liam Martinez  Password123!  10027  932-103-7306
# 28     Benjamin Smith  Password123!  10028  785-232-7104
# 29     James Williams  Password123!  10029  770-576-7793
# 30      Luna Anderson  Password123!  10030  845-522-3009
# 31     Jacob Martinez  Password123!  10031  806-647-5657
# 32      Noah Anderson  Password123!  10032  621-383-1437
# 33      Liam Martinez  Password123!  10033  729-037-8180
# 34     Evelyn Ramdial  Password123!  10034  611-784-3910
# 35       Lucas Wilson  Password123!  10035  861-356-0277
# 36  Theodore Williams  Password123!  10036  948-163-1861
# 37     Luna Hernandez  Password123!  10037  861-145-4700
# 38    Benjamin Miller  Password123!  10038  905-015-5673
# 39     Benjamin Davis  Password123!  10039  659-310-3293
# 40      Luna Martinez  Password123!  10040  657-551-8279
# 41  William Rodriguez  Password123!  10041  893-782-6828
# 42    Evelyn Martinez  Password123!  10042  621-627-1003
# 43       Noah Ramdial  Password123!  10043  779-802-7023
# 44       James Thomas  Password123!  10044  727-737-0954
#
#                             4                5            6      7
# 0                         CEO     Hartford, CT  16778800.00  10000
# 1       Data Engineer Manager     Hartford, CT    189612.01  10000
# 2        Senior Data Engineer   Saint Paul, MN    149812.69  10001
# 3        Senior Data Engineer  Hunt Valley, MD    164232.48  10001
# 4        Junior Data Engineer   Saint Paul, MN     99611.94  10001
# 5        Senior Data Engineer     Hartford, CT    180185.58  10001
# 6        Junior Data Engineer  Hunt Valley, MD     98954.28  10001
# 7        Junior Data Engineer   Saint Paul, MN    108377.22  10001
# 8        Junior Data Engineer     Hartford, CT    117637.93  10001
# 9        Junior Data Engineer  Hunt Valley, MD     94217.74  10001
# 10       Junior Data Engineer   Saint Paul, MN    107196.53  10001
# 11       Junior Data Engineer  Hunt Valley, MD     97882.12  10001
# 12       Senior Data Engineer     New York, NY    238494.82  10001
# 13       Junior Data Engineer  Hunt Valley, MD     96201.40  10001
# 14       Senior Data Engineer   Saint Paul, MN    157698.67  10001
# 15       Senior Data Engineer     New York, NY    239784.85  10001
# 16       Junior Data Engineer  Hunt Valley, MD     99257.70  10001
# 17       Junior Data Engineer   Saint Paul, MN     96867.22  10001
# 18       Senior Data Engineer     New York, NY    226453.54  10001
# 19       Senior Data Engineer     New York, NY    228734.25  10001
# 20       Senior Data Engineer     Hartford, CT    174341.16  10001
# 21                 HR Manager     New York, NY    163608.22  10000
# 22              HR Specialist  Hunt Valley, MD     66736.70  10021
# 23              HR Specialist     New York, NY    108039.58  10021
# 24          HR Representative     Hartford, CT     55619.29  10021
# 25              HR Specialist     Hartford, CT     72165.40  10021
# 26          HR Representative     New York, NY     74180.99  10021
# 27              HR Specialist     Hartford, CT     71292.70  10021
# 28          HR Representative  Hunt Valley, MD     51544.01  10021
# 29              HR Specialist     New York, NY     94086.70  10021
# 30              HR Specialist  Hunt Valley, MD     69964.95  10021
# 31              HR Specialist  Hunt Valley, MD     67754.15  10021
# 32          HR Representative     Hartford, CT     50260.76  10021
# 33          HR Representative     New York, NY     76614.61  10021
# 34              HR Specialist     Hartford, CT     78246.53  10021
# 35              HR Specialist     Hartford, CT     76610.33  10021
# 36              HR Specialist  Hunt Valley, MD     66737.51  10021
# 37              HR Specialist     Hartford, CT     73619.38  10021
# 38          HR Representative     New York, NY     69824.72  10021
# 39          HR Representative  Hunt Valley, MD     47260.30  10021
# 40          HR Representative  Hunt Valley, MD     50795.49  10021
# 41  Software Engineer Manager  Hunt Valley, MD    178002.95  10000
# 42   Junior Software Engineer   Saint Paul, MN     90508.76  10041
# 43   Junior Software Engineer   Saint Paul, MN     82684.89  10041
# 44   Senior Software Engineer   Saint Paul, MN    152618.84  10041

# %%
print(df[7].unique())
# Out:
# [10000 10001 10021 10041 10061 10081 10101 10121 10141 10161 10181 10201
#  10221 10241 10261 10281 10301 10321 10341 10361 10381 10401 10421 10441
#  10461 10481 10501 10521 10541 10561 10581 10601 10621 10641 10661 10681
#  10701 10721 10741 10761 10781 10801 10821 10841 10861 10881 10901 10921
#  10941 10961 10981]

# %%
# Write the data to the CSV file
with open('data.csv', "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(
        ["name", "password", "employee_id", "phone_number", "job_role", "work_location", "salary",
         "manager_id"]
    )
    writer.writerows(data_rows)

print("Data generation complete.")
# Out:
# Data generation complete.
