# %% [markdown]
# # Generate Data for Searchable Enterprise Directory Application

# %%
# import necessary packages

import csv
import random

# %% [markdown]
# ### Set up dicts and lists to create data

# %%
# Lists of possible names

first_names = ["Ava", "Noah", "Jacob", "Liam", "Noah", "Oliver", "James", "Elijah", "William", "Henry", "Lucas", "Benjamin", "Theodore",
               "Olivia", "Emma", "Charlotte", "Amelia", "Sophia", "Isabella", "Mia", "Evelyn", "Luna"]

last_names = ["Downey", "Ramdial", "Lettick", "Smith", "Johnson", "Williams", "Jones", "Brown", "Garcia", "Miller", "Davis", 
              "Rodriguez", "Martinez", "Hernandez", "Wilson", "Lopez", "Anderson", "Thomas", "Moore", "Jackson"]

# %%
# dictionaries needed to make data have some correlation

work_location_mult = {
    "Hartford, CT" : 1.217,
    "Saint Paul, MN" : 1.135,
    "Hunt Valley, MD" : 1.117,
    "New York, NY" : 1.670
}

job_role_mult = {
    "Junior Software Engineer" : 1.3,
    "Senior Software Engineer" : 2.12,
    "Software Engineer Manager" : 2.66,
    "Junior Data Engineer" : 1.5,
    "Senior Data Engineer" : 2.30,
    "Data Engineer Manager" : 2.60,
    "HR Representative" : 0.73,
    "HR Specialist" : 1,
    "HR Manager" : 1.66
}

job_roles_t1 = ['Software Engineer Manager', 'Data Engineer Manager', 'HR Manager']
job_roles_swe = ['Senior Software Engineer', 'Junior Software Engineer']
job_roles_de = ['Senior Data Engineer', 'Junior Data Engineer']
job_roles_hr = ['HR Specialist', 'HR Representative']

# %%
# constants among all rows

password = "Password123!"

# %% [markdown]
# ### generate the data

# %%
# generate phone number
# code modified from https://stackoverflow.com/questions/26226801/making-random-phone-number-xxx-xxx-xxxx

def gen_phone_num():
    first = str(random.randint(600,999))
    second = str(random.randint(1,888)).zfill(3)

    last = (str(random.randint(1,9998)).zfill(4))
    while last in ['1111','2222','3333','4444','5555','6666','7777','8888']:
        last = (str(random.randint(1,9998)).zfill(4))
        
    return '{}-{}-{}'.format(first,second, last)

# %%
# generate salary with noise multiplier

def gen_salary(job_role, work_location):
    salary = 60000 * job_role_mult.get(job_role) * work_location_mult.get(work_location)
    salary = salary * random.uniform(0.93, 1.08 ) # noise
    return round(salary, 2)

# %%
NUM_ROWS = 999
data_rows = []

# make CEO employee
name = "Alan Schnitzer"
employee_id = 10000
phone_number = gen_phone_num()
job_role = "CEO"
work_location = "Hartford, CT"
salary = 16778800
manager_id = 10000

data_row = [
    name,
    password,
    employee_id,
    phone_number,
    job_role,
    work_location,
    salary,
    manager_id
]

# Add the data row to the list
data_rows.append(data_row)

for x in range(NUM_ROWS):
    name = "{} {}".format(random.choice(first_names), random.choice(last_names))
    employee_id = x + 10001
    phone_number = gen_phone_num()
    work_location = random.choice(list(work_location_mult.keys()))

    # determine manager and job role
    if (x % 20 == 0): # management roles reporting to CEO
        job_role = random.choice(job_roles_t1)
        manager_id = 10000
    elif (data_rows[x-(x%20)+1][4] == "Software Engineer Manager"): # report to swe manager
        job_role = random.choice(job_roles_swe)
        manager_id = data_rows[x-(x%20)+1][2]
    elif (data_rows[x-(x%20)+1][4] == "Data Engineer Manager"): # report to de manager
        job_role = random.choice(job_roles_de)
        manager_id = data_rows[x-(x%20)+1][2]
    elif (data_rows[x-(x%20)+1][4] == "HR Manager"): # report to hr manager
        job_role = random.choice(job_roles_hr)
        manager_id = data_rows[x-(x%20)+1][2]

    salary = gen_salary(job_role, work_location)

    data_row = [
        name,
        password,
        employee_id,
        phone_number,
        job_role,
        work_location,
        salary,
        manager_id
    ]

    # Add the data row to the list
    data_rows.append(data_row)

# %%
# test row outputs

print(data_rows[0])
print(data_rows[1])
print(data_rows[10])
print(data_rows[11])
print(data_rows[999])
# Out:
# ['Alan Schnitzer', 'Password123!', 10000, '948-397-2668', 'CEO', 'Hartford, CT', 16778800, 10000]
# ['Theodore Garcia', 'Password123!', 10001, '844-735-1217', 'Software Engineer Manager', 'Hartford, CT', 191618.77, 10000]
# ['Ava Martinez', 'Password123!', 10010, '702-738-6078', 'Junior Software Engineer', 'Hartford, CT', 101851.55, 10001]
# ['Olivia Jackson', 'Password123!', 10011, '789-677-1582', 'Junior Software Engineer', 'Hartford, CT', 90700.19, 10001]
# ['Jacob Williams', 'Password123!', 10999, '953-529-3517', 'HR Representative', 'Saint Paul, MN', 46877.86, 10981]

# %%
import pandas as pd
df = pd.DataFrame(data_rows)
df.head(45)
# Out:
#                     0             1      2             3  \
# 0      Alan Schnitzer  Password123!  10000  948-397-2668
# 1     Theodore Garcia  Password123!  10001  844-735-1217
# 2          Luna Davis  Password123!  10002  768-021-7000
# 3      Amelia Ramdial  Password123!  10003  616-209-2871
# 4     Charlotte Jones  Password123!  10004  846-490-4884
# 5      Liam Rodriguez  Password123!  10005  989-565-2850
# 6        Noah Johnson  Password123!  10006  738-869-5464
# 7         Luna Garcia  Password123!  10007  979-702-5522
# 8         Noah Wilson  Password123!  10008  675-067-7079
# 9    William Anderson  Password123!  10009  915-672-3646
# 10       Ava Martinez  Password123!  10010  702-738-6078
# 11     Olivia Jackson  Password123!  10011  789-677-1582
# 12      Evelyn Wilson  Password123!  10012  648-058-4448
# 13     Noah Hernandez  Password123!  10013  703-726-8475
# 14      Elijah Garcia  Password123!  10014  907-528-3815
# 15     Isabella Davis  Password123!  10015  677-209-4114
# 16      Henry Johnson  Password123!  10016  690-112-6110
# 17    Benjamin Garcia  Password123!  10017  810-619-4131
# 18        Liam Garcia  Password123!  10018  869-423-0439
# 19       James Downey  Password123!  10019  965-074-9129
# 20         Ava Miller  Password123!  10020  793-779-9673
# 21    Benjamin Garcia  Password123!  10021  629-348-7805
# 22       Lucas Miller  Password123!  10022  792-007-6382
# 23    William Lettick  Password123!  10023  828-607-2267
# 24         Mia Miller  Password123!  10024  935-251-8536
# 25       Noah Ramdial  Password123!  10025  823-150-0203
# 26    Sophia Anderson  Password123!  10026  970-549-4628
# 27    Benjamin Miller  Password123!  10027  861-355-5468
# 28         Ava Miller  Password123!  10028  741-696-8931
# 29        Liam Downey  Password123!  10029  602-098-5553
# 30      Evelyn Miller  Password123!  10030  842-241-6821
# 31        Lucas Jones  Password123!  10031  866-049-1863
# 32       Amelia Davis  Password123!  10032  631-396-7716
# 33      Evelyn Wilson  Password123!  10033  628-852-8259
# 34  William Rodriguez  Password123!  10034  854-787-2705
# 35     Benjamin Brown  Password123!  10035  928-218-2365
# 36       Mia Anderson  Password123!  10036  722-822-7041
# 37        Henry Lopez  Password123!  10037  624-298-7353
# 38   Isabella Ramdial  Password123!  10038  848-823-9211
# 39         Luna Brown  Password123!  10039  987-790-3483
# 40      Henry Jackson  Password123!  10040  714-077-1315
# 41         Emma Lopez  Password123!  10041  732-154-4113
# 42       Evelyn Brown  Password123!  10042  752-214-5712
# 43      Olivia Downey  Password123!  10043  780-564-0595
# 44     William Garcia  Password123!  10044  610-363-8859
#
#                             4                5            6      7
# 0                         CEO     Hartford, CT  16778800.00  10000
# 1   Software Engineer Manager     Hartford, CT    191618.77  10000
# 2    Junior Software Engineer     Hartford, CT     91317.59  10001
# 3    Senior Software Engineer   Saint Paul, MN    145288.41  10001
# 4    Junior Software Engineer  Hunt Valley, MD     89678.62  10001
# 5    Senior Software Engineer   Saint Paul, MN    144244.83  10001
# 6    Junior Software Engineer     Hartford, CT     98360.07  10001
# 7    Senior Software Engineer     New York, NY    207469.95  10001
# 8    Senior Software Engineer     New York, NY    200313.74  10001
# 9    Junior Software Engineer     New York, NY    134737.77  10001
# 10   Junior Software Engineer     Hartford, CT    101851.55  10001
# 11   Junior Software Engineer     Hartford, CT     90700.19  10001
# 12   Senior Software Engineer     Hartford, CT    148709.31  10001
# 13   Junior Software Engineer     New York, NY    132166.43  10001
# 14   Junior Software Engineer   Saint Paul, MN     92048.08  10001
# 15   Junior Software Engineer  Hunt Valley, MD     91864.04  10001
# 16   Junior Software Engineer     New York, NY    137486.42  10001
# 17   Junior Software Engineer     Hartford, CT    101897.32  10001
# 18   Senior Software Engineer     Hartford, CT    153435.17  10001
# 19   Junior Software Engineer     Hartford, CT    100900.09  10001
# 20   Senior Software Engineer     Hartford, CT    146074.95  10001
# 21      Data Engineer Manager     Hartford, CT    201630.96  10000
# 22       Senior Data Engineer   Saint Paul, MN    152134.69  10021
# 23       Junior Data Engineer     Hartford, CT    114913.66  10021
# 24       Junior Data Engineer   Saint Paul, MN    102232.84  10021
# 25       Junior Data Engineer     Hartford, CT    106115.95  10021
# 26       Senior Data Engineer     Hartford, CT    165593.42  10021
# 27       Senior Data Engineer   Saint Paul, MN    161743.73  10021
# 28       Junior Data Engineer   Saint Paul, MN    109350.02  10021
# 29       Senior Data Engineer     New York, NY    230902.12  10021
# 30       Senior Data Engineer   Saint Paul, MN    158005.84  10021
# 31       Senior Data Engineer     New York, NY    247982.59  10021
# 32       Junior Data Engineer  Hunt Valley, MD     94561.28  10021
# 33       Senior Data Engineer     New York, NY    214398.95  10021
# 34       Junior Data Engineer     Hartford, CT    113568.45  10021
# 35       Junior Data Engineer     New York, NY    141737.02  10021
# 36       Junior Data Engineer     New York, NY    143733.84  10021
# 37       Senior Data Engineer     Hartford, CT    158636.46  10021
# 38       Senior Data Engineer   Saint Paul, MN    161540.85  10021
# 39       Junior Data Engineer     Hartford, CT    102680.14  10021
# 40       Junior Data Engineer  Hunt Valley, MD     93805.03  10021
# 41                 HR Manager     Hartford, CT    125938.66  10000
# 42          HR Representative     Hartford, CT     54450.30  10041
# 43          HR Representative  Hunt Valley, MD     51816.91  10041
# 44              HR Specialist     Hartford, CT     77794.44  10041

# %%
print(df[7].unique())
# Out:
# [10000 10001 10021 10041 10061 10081 10101 10121 10141 10161 10181 10201
#  10221 10241 10261 10281 10301 10321 10341 10361 10381 10401 10421 10441
#  10461 10481 10501 10521 10541 10561 10581 10601 10621 10641 10661 10681
#  10701 10721 10741 10761 10781 10801 10821 10841 10861 10881 10901 10921
#  10941 10961 10981]

# %%
# Write the data to the CSV file
with open('data.csv', "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(
        ["name", "password", "employee_id", "phone_number", "job_role", "work_location", "salary",
         "manager_id"]
    )
    writer.writerows(data_rows)

print("Data generation complete.")
# Out:
# Data generation complete.
