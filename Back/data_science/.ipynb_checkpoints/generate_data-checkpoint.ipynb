# %% [markdown]
# # Generate Data for Searchable Enterprise Directory Application

# %%
# import necessary packages

import csv
import random

# %% [markdown]
# ### Set up dicts and lists to create data

# %%
# Lists of possible names

first_names = ["Ava", "Noah", "Jacob", "Liam", "Noah", "Oliver", "James", "Elijah", "William", "Henry", "Lucas", "Benjamin", "Theodore",
               "Olivia", "Emma", "Charlotte", "Amelia", "Sophia", "Isabella", "Mia", "Evelyn", "Luna"]

last_names = ["Downey", "Ramdial", "Lettick", "Smith", "Johnson", "Williams", "Jones", "Brown", "Garcia", "Miller", "Davis", 
              "Rodriguez", "Martinez", "Hernandez", "Wilson", "Lopez", "Anderson", "Thomas", "Moore", "Jackson"]

# %%
# dictionaries needed to make data have some correlation

work_location_mult = {
    "Hartford, CT" : 1.217,
    "Saint Paul, MN" : 1.135,
    "Hunt Valley, MD" : 1.117,
    "New York, NY" : 1.670
}

job_role_mult = {
    "Junior Software Engineer" : 1.3,
    "Senior Software Engineer" : 2.12,
    "Software Engineer Manager" : 2.66,
    "Junior Data Engineer" : 1.5,
    "Senior Data Engineer" : 2.30,
    "Data Engineer Manager" : 2.60,
    "HR Representative" : 0.73,
    "HR Specialist" : 1,
    "HR Manager" : 1.66
}

job_roles_t1 = ['Software Engineer Manager', 'Data Engineer Manager', 'HR Manager']
job_roles_swe = ['Senior Software Engineer', 'Junior Software Engineer']
job_roles_de = ['Senior Data Engineer', 'Junior Data Engineer']
job_roles_hr = ['HR Specialist', 'HR Representative']

# %%
# constants among all rows

password = "Password123!"

# %% [markdown]
# ### generate the data

# %%
# generate phone number
# code modified from https://stackoverflow.com/questions/26226801/making-random-phone-number-xxx-xxx-xxxx

def gen_phone_num():
    first = str(random.randint(600,999))
    second = str(random.randint(1,888)).zfill(3)

    last = (str(random.randint(1,9998)).zfill(4))
    while last in ['1111','2222','3333','4444','5555','6666','7777','8888']:
        last = (str(random.randint(1,9998)).zfill(4))
        
    return '{}-{}-{}'.format(first,second, last)

# %%
# generate salary with noise multiplier

def gen_salary(job_role, work_location):
    salary = 60000 * job_role_mult.get(job_role) * work_location_mult.get(work_location)
    salary = salary * random.uniform(0.93, 1.08 ) # noise
    return round(salary, 2)

# %%
NUM_ROWS = 999
data_rows = []

# make CEO employee
name = "Alan Schnitzer"
employee_id = 10000
phone_number = gen_phone_num()
job_role = "CEO"
work_location = "Hartford, CT"
salary = 16778800
manager_id = 10000

data_row = [
    name,
    password,
    employee_id,
    phone_number,
    job_role,
    work_location,
    salary,
    manager_id
]

# Add the data row to the list
data_rows.append(data_row)

for x in range(NUM_ROWS):
    name = "{} {}".format(random.choice(first_names), random.choice(last_names))
    employee_id = x + 10001
    phone_number = gen_phone_num()
    work_location = random.choice(list(work_location_mult.keys()))

    # determine manager and job role
    if (x % 20 == 0): # management roles reporting to CEO
        job_role = random.choice(job_roles_t1)
        manager_id = 10000
    elif (data_rows[x-(x%20)+1][4] == "Software Engineer Manager"): # report to swe manager
        job_role = random.choice(job_roles_swe)
        manager_id = data_rows[x-(x%20)+1][2]
    elif (data_rows[x-(x%20)+1][4] == "Data Engineer Manager"): # report to de manager
        job_role = random.choice(job_roles_de)
        manager_id = data_rows[x-(x%20)+1][2]
    elif (data_rows[x-(x%20)+1][4] == "HR Manager"): # report to hr manager
        job_role = random.choice(job_roles_hr)
        manager_id = data_rows[x-(x%20)+1][2]

    salary = gen_salary(job_role, work_location)

    data_row = [
        name,
        password,
        employee_id,
        phone_number,
        job_role,
        work_location,
        salary,
        manager_id
    ]

    # Add the data row to the list
    data_rows.append(data_row)

# %%
# test row outputs

print(data_rows[0])
print(data_rows[1])
print(data_rows[10])
print(data_rows[11])
print(data_rows[999])
# Out:
# ['Alan Schnitzer', 'Password123!', 10000, '933-399-1433', 'CEO', 'Hartford, CT', 16778800, 10000]
# ['Isabella Downey', 'Password123!', 10001, '883-209-0229', 'HR Manager', 'Hartford, CT', 113191.4, 10000]
# ['Lucas Garcia', 'Password123!', 10010, '622-745-9651', 'HR Representative', 'Hartford, CT', 52171.96, 10001]
# ['Noah Miller', 'Password123!', 10011, '749-457-2724', 'HR Representative', 'Hartford, CT', 55605.43, 10001]
# ['Isabella Lopez', 'Password123!', 10999, '677-660-2207', 'HR Specialist', 'Saint Paul, MN', 73188.06, 10981]

# %%
import pandas as pd
df = pd.DataFrame(data_rows)
df.head(45)
# Out:
#                      0             1      2             3  \
# 0       Alan Schnitzer  Password123!  10000  933-399-1433
# 1      Isabella Downey  Password123!  10001  883-209-0229
# 2         Olivia Lopez  Password123!  10002  716-476-7649
# 3       Henry Williams  Password123!  10003  924-293-6309
# 4     Amelia Hernandez  Password123!  10004  660-452-4687
# 5        Oliver Thomas  Password123!  10005  971-644-9735
# 6         Ava Martinez  Password123!  10006  713-358-7962
# 7         Evelyn Jones  Password123!  10007  760-044-4968
# 8        William Davis  Password123!  10008  983-166-9434
# 9      Benjamin Miller  Password123!  10009  711-710-0376
# 10        Lucas Garcia  Password123!  10010  622-745-9651
# 11         Noah Miller  Password123!  10011  749-457-2724
# 12        Evelyn Brown  Password123!  10012  880-138-4557
# 13    Isabella Ramdial  Password123!  10013  894-734-0378
# 14      Sophia Jackson  Password123!  10014  873-493-7578
# 15        Evelyn Brown  Password123!  10015  642-751-7466
# 16     Evelyn Anderson  Password123!  10016  810-515-2970
# 17   Theodore Williams  Password123!  10017  669-325-9368
# 18           Mia Davis  Password123!  10018  658-113-2581
# 19        Oliver Moore  Password123!  10019  978-767-2544
# 20     Jacob Rodriguez  Password123!  10020  813-888-0056
# 21    Charlotte Wilson  Password123!  10021  983-110-6989
# 22      Liam Rodriguez  Password123!  10022  822-216-5787
# 23        Ava Anderson  Password123!  10023  668-594-9605
# 24      James Williams  Password123!  10024  970-070-4659
# 25  Charlotte Martinez  Password123!  10025  917-495-9511
# 26  Isabella Hernandez  Password123!  10026  803-774-4491
# 27      William Garcia  Password123!  10027  617-723-7311
# 28   Charlotte Johnson  Password123!  10028  911-753-5616
# 29         James Jones  Password123!  10029  764-742-4103
# 30        Mia Williams  Password123!  10030  746-332-7720
# 31   William Hernandez  Password123!  10031  960-011-0212
# 32      Henry Williams  Password123!  10032  779-184-0289
# 33           Mia Smith  Password123!  10033  992-503-6692
# 34         Liam Miller  Password123!  10034  650-600-4081
# 35        Elijah Lopez  Password123!  10035  997-439-7805
# 36      Lucas Martinez  Password123!  10036  897-145-9486
# 37         Noah Thomas  Password123!  10037  986-486-8233
# 38     Oliver Anderson  Password123!  10038  812-459-3824
# 39      Amelia Lettick  Password123!  10039  677-524-3581
# 40          Liam Lopez  Password123!  10040  941-507-1873
# 41        Jacob Garcia  Password123!  10041  857-316-7175
# 42          Luna Davis  Password123!  10042  715-615-0730
# 43   Theodore Anderson  Password123!  10043  633-834-2799
# 44          Noah Jones  Password123!  10044  911-587-1584
#
#                         4                5            6      7
# 0                     CEO     Hartford, CT  16778800.00  10000
# 1              HR Manager     Hartford, CT    113191.40  10000
# 2           HR Specialist  Hunt Valley, MD     70760.78  10001
# 3           HR Specialist     New York, NY    104130.84  10001
# 4       HR Representative     New York, NY     74193.31  10001
# 5       HR Representative     New York, NY     71202.54  10001
# 6       HR Representative  Hunt Valley, MD     49749.27  10001
# 7           HR Specialist     Hartford, CT     74467.91  10001
# 8       HR Representative     Hartford, CT     52288.27  10001
# 9       HR Representative     New York, NY     74374.25  10001
# 10      HR Representative     Hartford, CT     52171.96  10001
# 11      HR Representative     Hartford, CT     55605.43  10001
# 12      HR Representative  Hunt Valley, MD     46188.88  10001
# 13      HR Representative  Hunt Valley, MD     49352.77  10001
# 14          HR Specialist  Hunt Valley, MD     66714.63  10001
# 15          HR Specialist     New York, NY     99220.51  10001
# 16          HR Specialist  Hunt Valley, MD     69145.67  10001
# 17          HR Specialist     New York, NY    103380.66  10001
# 18      HR Representative  Hunt Valley, MD     51202.64  10001
# 19          HR Specialist   Saint Paul, MN     71029.25  10001
# 20      HR Representative   Saint Paul, MN     51299.71  10001
# 21  Data Engineer Manager     New York, NY    244985.18  10000
# 22   Senior Data Engineer     Hartford, CT    180739.17  10021
# 23   Junior Data Engineer     Hartford, CT    110206.20  10021
# 24   Senior Data Engineer  Hunt Valley, MD    149244.84  10021
# 25   Senior Data Engineer   Saint Paul, MN    163829.02  10021
# 26   Senior Data Engineer     Hartford, CT    173728.00  10021
# 27   Senior Data Engineer     Hartford, CT    171451.65  10021
# 28   Junior Data Engineer   Saint Paul, MN     96848.95  10021
# 29   Junior Data Engineer   Saint Paul, MN     97421.41  10021
# 30   Senior Data Engineer   Saint Paul, MN    156617.96  10021
# 31   Senior Data Engineer   Saint Paul, MN    149071.25  10021
# 32   Senior Data Engineer  Hunt Valley, MD    155815.92  10021
# 33   Senior Data Engineer     Hartford, CT    168902.08  10021
# 34   Senior Data Engineer   Saint Paul, MN    151339.74  10021
# 35   Senior Data Engineer     Hartford, CT    176718.94  10021
# 36   Junior Data Engineer   Saint Paul, MN    106966.75  10021
# 37   Junior Data Engineer  Hunt Valley, MD     99331.74  10021
# 38   Junior Data Engineer     Hartford, CT    111034.85  10021
# 39   Senior Data Engineer  Hunt Valley, MD    151968.68  10021
# 40   Senior Data Engineer     Hartford, CT    162247.27  10021
# 41  Data Engineer Manager     Hartford, CT    195468.51  10000
# 42   Senior Data Engineer     New York, NY    229239.35  10041
# 43   Senior Data Engineer     Hartford, CT    158699.88  10041
# 44   Junior Data Engineer     Hartford, CT    113944.62  10041

# %%
print(df[7].unique())
# Out:
# [10000 10001 10021 10041 10061 10081 10101 10121 10141 10161 10181 10201
#  10221 10241 10261 10281 10301 10321 10341 10361 10381 10401 10421 10441
#  10461 10481 10501 10521 10541 10561 10581 10601 10621 10641 10661 10681
#  10701 10721 10741 10761 10781 10801 10821 10841 10861 10881 10901 10921
#  10941 10961 10981]

# %%
# Write the data to the CSV file
with open('data.csv', "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(
        ["name", "password", "employee_id", "phone_number", "job_role", "work_location", "salary",
         "manager_id"]
    )
    writer.writerows(data_rows)

print("Data generation complete.")
# Out:
# Data generation complete.
